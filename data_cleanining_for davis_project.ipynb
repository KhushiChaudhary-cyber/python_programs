# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushiChaudhary-cyber/Data-_Visualization/blob/main/data_cleanining_for%20davis_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data cleaning**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-47b190df-56fa-414c-aa2e-aa0da1322d65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47b190df-56fa-414c-aa2e-aa0da1322d65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel("enterprise_retail_dataset.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Order_ID             94940 non-null   object
#  1   Order_Date           94998 non-null   object
#  2   Delivery_Date        94923 non-null   object
#  3   Customer_ID          95028 non-null   object
#  4   Customer_Age         100000 non-null  float64
#  5   Gender               95078 non-null   object
#  6   Country              95001 non-null   object
#  7   State                95043 non-null   object
#  8   City                 94921 non-null   object
#  9   Region               94987 non-null   object
#  10  Category             94976 non-null   object
#  11  Sub_Category         94943 non-null   object
#  12  Product_Name         94955 non-null   object
#  13  Quantity             94986 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID               5060
# Order_Date             5002
# Delivery_Date          5077
# Customer_ID            4972
# Customer_Age              0
# Gender                 4922
# Country                4999
# State                  4957
# City                   5079
# Region                 5013
# Category               5024
# Sub_Category           5057
# Product_Name           5045
# Quantity               5014
# Unit_Price             5109
# Sales                  5061
# Cost                   4947
# Profit                    0
# Discount_Percentage    4991
# Payment_Method         4975
# Shipping_Mode          4840
# Delivery_Time_Days     4980
# Return_Status          5006
# Customer_Segment       5075
# Rating                    0
# dtype: int64

# %%
df['Customer_Age'] = df['Customer_Age'].fillna(df['Customer_Age'].median())

df['Profit'] = df['Profit'].fillna(df['Profit'].median())

df['Rating'] = df['Rating'].fillna(df['Rating'].median())

# %%
df['Payment_Method'] = df['Payment_Method'].fillna(
    df['Payment_Method'].mode()[0]
)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Category'].unique()
# Out:
# array(['Clothing', 'Home & Lifestyle', 'Electronics', nan], dtype=object)

# %%
df['Payment_Method'].unique()
# Out:
# array(['Paypal', 'PayPal', 'credit card', 'Credit Card'], dtype=object)

# %%
df[(df['Customer_Age'] < 18) | (df['Customer_Age'] > 80)]
# Out:
#          Order_ID           Order_Date        Delivery_Date Customer_ID  \
# 3      ORD0000003  2023-06-29 23:05:13  2023-07-03 23:05:13   CUST00003
# 9      ORD0000009  2023-09-16 04:37:15  2023-09-19 04:37:15   CUST00009
# 14     ORD0000014  2023-12-28 12:32:20  2024-01-06 12:32:20   CUST00014
# 32     ORD0000032  2024-06-20 18:02:33  2024-06-23 18:02:33   CUST00032
# 72     ORD0000072                  NaN  2023-07-26 17:56:27   CUST00072
# ...           ...                  ...                  ...         ...
# 99798  ORD0099798  2024-03-15 18:26:07                  NaN         NaN
# 99840  ORD0099840  2024-09-20 21:44:37  2024-09-27 21:44:37   CUST49840
# 99876  ORD0099876  2024-07-23 08:57:07  2024-07-29 08:57:07   CUST49876
# 99885         NaN  2024-08-06 20:51:15  2024-08-15 20:51:15   CUST49885
# 99946  ORD0099946  2023-10-15 07:01:43  2023-10-18 07:01:43   CUST49946
#
#        Customer_Age  Gender  Country   State       City         Region  ...  \
# ...

# %%
median_age = df['Customer_Age'].median()

df.loc[
    (df['Customer_Age'] < 18) |
    (df['Customer_Age'] > 80),
    'Customer_Age'
] = median_age

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'])

# %%
df[['Order_Date','Delivery_Date']].dtypes
# Out:
# Order_Date       datetime64[ns]
# Delivery_Date    datetime64[ns]
# dtype: object

# %%
df.to_excel("cleaned_enterprise_retail_dataset.xlsx", index=False)

# %%
from google.colab import files
files.download("cleaned_enterprise_retail_dataset.xlsx")
