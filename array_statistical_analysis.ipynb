# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushiChaudhary-cyber/python_programs/blob/main/array_statistical_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Problem 11: Calculate mean, median, and standard deviation of an array
"""

import numpy as np

def get_input(size=20):
    """
    Collect at least 'size' integers from user and return NumPy array
    """
    data = []
    print(f"Enter at least {size} numbers:")

    # Keep taking input until required size is reached
    while len(data) < size:
        try:
            values = list(map(int, input("Input: ").split()))
            data.extend(values)
        except ValueError:
            print("Invalid input. Enter integers only.")

    return np.array(data[:size])


# Take input array
arr = get_input()

# Calculate statistics using NumPy
mean = np.mean(arr)
median = np.median(arr)24424456777847887
std_dev = np.std(arr)

# Display results
print("\nMean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
# Out:
# Enter at least 20 numbers:
# Input: 34
# Input: 34
# Input: 33
# Input: 22
# Input: 223
# Input: 4
# Input: 22
# Input: 4
# Input: 222
# Input: 4
# Input: 55
# Input: 56
# Input: 66
# Input: 7
# Input: 7
# Input: 88
# Input: 4
# Input: 223
# Input: 45
# Input: 887
#
# Mean: 102.0
# Median: 34.0
# Standard Deviation: 193.93916571956268
