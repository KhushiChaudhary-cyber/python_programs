# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushiChaudhary-cyber/python_programs/blob/main/array_elementwise_product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Problem 12: Perform element-wise multiplication of two arrays
"""

import numpy as np

def get_input(size=20, name="array"):
    """
    Collect array input from user
    """
    data = []
    print(f"Enter at least {size} elements for {name}:")

    while len(data) < size:
        try:
            data.extend(map(int, input("Input: ").split()))
        except ValueError:
            print("Invalid input.")

    return np.array(data[:size])


# Take both arrays as input
arr1 = get_input(name="Array 1")
arr2 = get_input(name="Array 2")

# Perform element-wise multiplication
result = arr1 * arr2

# Display result
print("\nResult:", result)3
# Out:
# Enter at least 20 elements for Array 1:
# Input: 34
# Input: 45
# Input: 56
# Input: 67
# Input: 67
# Input: 78
# Input: 89
# Input: 89
# Input: 79
# Input: 59
# Input: 40
# Input: 30
# Input: 20
# Input: 22
# Input: 34
# Input: 56
# Input: 50
# Input: 49
# Input: 47
# Input: 39
# Enter at least 20 elements for Array 2:
# Input: 34
# Input: 23
# Input: 24
# Input: 24
# Input: 22
# Input: 44
# Input: 55
# Input: 6
# Input: 55
# Input: 78
# Input: 57
# Input: 46
# Input: 4
# Input: 67
# Input: 778
# Input: 78
# Input: 88
# Input: 99
# Input: 00
# Input: 67
#
# Result: [ 1156  1035  1344  1608  1474  3432  4895   534  4345  4602  2280  1380
#     80  1474 26452  4368  4400  4851     0  2613]
